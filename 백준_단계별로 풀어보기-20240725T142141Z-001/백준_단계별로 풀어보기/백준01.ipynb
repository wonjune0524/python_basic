# %%
# 01

print("Hello World!")
# Out:
# Hello World!

# %%
# 02

A, B = input().split()

print(int(A) + int(B))
# Out:
# 1 2
# 3

# %%
# 03

A, B = input().split()

print(int(A) - int(B))
# Out:
# 3 2
# 1

# %%
# 04

A, B = input().split()
print(int(A) * int(B))
# Out:
# 2 3
# 6

# %%
# 05

A, B = input().split()

print(float(A) / float(B))
# Out:
# 1 3
# 0.3333333333333333

# %%
# 06

A, B = input().split()
x = int(A) / int(B)

print(int(A) + int(B))
print(int(A) - int(B))
print(int(A) * int(B))
print(int(x))
print(int(A) % int(B))
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1

# %%
# 07

id = input()

print(f"{id}??!")
# Out:
# joonas
# joonas??!

# %%
# 08

year = int(input())

print(year - 543)
# Out:
# 2541
# 1998

# %%
# 09

A, B, C = input().split()

print((int(A) + int(B)) % int(C))
print(((int(A) % int(C)) + (int(B) % int(C))) % int(C))
print((int(A) * int(B)) % int(C))
print(((int(A) % int(C)) * (int(B) % int(C))) % int(C))
# Out:
# 5 8 4
# 1
# 1
# 0
# 0

# %%
# 10

num1 = input()
num2 = input()

print(int(num1) * int(num2[2]))
print(int(num1) * int(num2[1]))
print(int(num1) * int(num2[0]))
print(int(num1) * int(num2[2]) + (int(num1) * int(num2[1])) * 10 + ((int(num1) * int(num2[0])) * 100))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720

# %%
# 11

A, B, C = input().split()

print(int(A) + int(B) + int(C))
# Out:
# 77 77 7777
# 7931

# %%
# 12

print("\    /\\")
print(" )  ( ')")
print("(  /  )")
print(" \(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
# 13

print("|\_/|")
print("|q p|   /}")
print("( 0 )\"\"\"\\")
print("|\"^\"`    |")
print("||_/=\\\\__|")
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
